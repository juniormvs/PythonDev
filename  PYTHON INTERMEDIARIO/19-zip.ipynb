# %% [markdown]
# Zip
# - É combinar múltiplos iteráveis (lista, ou tupla) em um único iterável

# %%
nomes = ["Aline", "Bob", "Charlie"]
idades = [25, 30,35]

# %%
for nome, idade in zip(nomes, idades):
    print(f"Nome: {nome}, Idade: {idade}")
# Out:
# Nome: Aline, Idade: 25
# Nome: Bob, Idade: 30
# Nome: Charlie, Idade: 35

# %%
#Converter o terável em um dicionário
pessoas = dict(zip(nomes, idades))
pessoas
# Out:
# {'Aline': 25, 'Bob': 30, 'Charlie': 35}

# %%
# Criando um dicionário somente com as pessoas que possuem mais de 30 anos
pessoas_acima_de_30 = {nome: idade for  nome, idade in pessoas.items() if idade > 30}
pessoas_acima_de_30
# Out:
# {'Charlie': 35}
