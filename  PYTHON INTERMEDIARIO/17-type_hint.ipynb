# %% [markdown]
# Type Hint
# - É uma maneira de indicar o tipo de variáveis, parâmetros e valores de retorno de função.

# %%
def soma(a: int, b: int) -> int:
    return a + b

# %%
soma(9,10)
# Out:
# 19

# %%
from typing import List

# %%
class Estudante:
    def __init__(self, nome: str, notas: List[float]) -> None:
        self.nome = nome
        self.notas = notas

    def media(self)-> float:
        return sum(self.notas) / len(self.notas)

# %%
def alunos_acima_da_media(alunos: List[Estudante], media_minima: float) -> List[str]:
    return [aluno.nome for aluno in alunos if aluno.media() >= media_minima]

# %%
alunos = [
    Estudante("Aline",  [7.5, 8.9, 9.0]),
    Estudante("Bob",    [6.5, 4.9, 4.0]),
    Estudante("Raquel", [8.5, 9.9, 10.0]),
    Estudante("Carlos", [4.5, 7.9, 8.0]),
    Estudante("Jaqueline", [3.5, 5.9, 1.0])
]

# %%
resultados = alunos_acima_da_media(alunos,8.0)
resultados
# Out:
# ['Aline', 'Raquel']
